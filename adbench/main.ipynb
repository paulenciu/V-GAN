# %% [markdown]
# ADBench Unsupervised methods
# ```
# ['IForest', 'OCSVM', 'CBLOF', 'COF', 'COPOD', 'ECOD', 'FeatureBagging', 'HBOS', 'KNN', 'LODA','LOF', 'LSCP', 'MCD', 'PCA', 'SOD', 'SOGAAL', 'MOGAAL', 'DeepSVDD']
# ```
# Missing: Lunar

# %%
import numpy as np

dataset = np.load("../.venv/lib/python3.9/site-packages/adbench/datasets/CV_by_ResNet18/MVTec-AD_bottle.npz", allow_pickle=True)

# %%
x = dataset["X"]
y = dataset["y"]

# %%
x[0].shape
# Out:
# (512,)

# %%
from adbench.run import RunPipeline

run = RunPipeline(suffix="ADBench", parallel="unsupervise")
run.run(dataset)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 from adbench.run import RunPipeline
# ----> 3 run = RunPipeline(suffix="ADBench", parallel="unsupervise")
#       4 run.run(dataset)
#
# File ~/PycharmProjects/V-GAN/.venv/lib/python3.9/site-packages/adbench/run.py:82, in RunPipeline.__init__(self, suffix, mode, parallel, generate_duplicates, n_samples_threshold, realistic_synthetic_mode, noise_type)
#      80 # unsupervised algorithms
#      81 if self.parallel == 'unsupervise':
# ---> 82     from adbench.baseline.PyOD import PYOD
#      83     from adbench.baseline.DAGMM.run import DAGMM
#      85     # from pyod
#
# File ~/PycharmProjects/V-GAN/.venv/lib/python3.9/site-packages/adbench/baseline/PyOD.py:5
#       2 import numpy as np
#       4 #add the baselines from the pyod package
# ----> 5 from pyod.models.iforest import IForest
# ...
